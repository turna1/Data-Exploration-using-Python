# %% [markdown]
# <a href="https://colab.research.google.com/github/turna1/Data-Exploration-using-Python/blob/main/cisc121_welcome_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1

# %%
print("Welcome to CISC121: Intoduction to computer Science")

# %% [markdown]
# # Section 2

# %%
x = 5
y = 10

# %%
import time
print("sleeping")
time.sleep(30)
print("done sleeping")
# Out:
# sleeping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-440008782.py in <cell line: 0>()
#       1 import time
#       2 print("sleeping")
# ----> 3 time.sleep(30)
#       4 print("done sleeping")
#
# KeyboardInterrupt:

# %%
import numpy as np
np.random.rand(10)

# %%
x = 1
y = 4

if (1 - x) != 0:
    z = y / (1 - x)
    print(z)
else:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
# improrting the library
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
! git clone https://github.com/turna1/Brush-of-Breath.git
# Out:
# Cloning into 'Brush-of-Breath'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 106 (delta 45), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (106/106), 8.83 MiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
